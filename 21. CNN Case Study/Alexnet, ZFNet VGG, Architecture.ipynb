# %% [markdown]
# ![Alexnet%20Architecture.GIF](attachment:Alexnet%20Architecture.GIF)
# - NORM above is LOCAL RESPONSE NORMALIZATION not used now days
# - FC is fully Connected layer

# %% [markdown]
# ![j1.GIF](attachment:j1.GIF)

# %% [markdown]
# ![j2.GIF](attachment:j2.GIF)

# %% [markdown]
# ![j3.GIF](attachment:j3.GIF)

# %% [markdown]
# - **Depthwise Separable Convolution is used by MobileNet**
