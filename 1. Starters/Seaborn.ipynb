# %%
import seaborn as sns
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips, estimator=np.std)

# %%
sns.countplot(x='sex', data= tips)

# %%
sns.countplot(x = 'time', data = tips)

# %%
sns.boxplot(x= 'day',y= 'total_bill', data = tips) # show min and max values

# %%
sns.boxplot(x= 'day',y= 'total_bill', data = tips, hue = 'smoker')

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex',split = True)

# %%
sns.distplot(tips['total_bill'], bins = 30)

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.jointplot(x ='total_bill' , y = 'tip' , data = tips)
# this plot shows that
# if total_bill is 10 then customer gives 1 as tips similary for 50 its around 9 
# that shows it is positive line increasing positively

# %%
sns.jointplot(x ='total_bill' , y = 'tip' , data = tips, color ='r', kind = 'hex')

# %% [markdown]
# ## KDE mean KERNEL DENSITY ESTIMATION

# %%
sns.jointplot(x ='total_bill' , y = 'tip' , data = tips, color ='r', kind = 'kde')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_corr = tips.corr()
tips_corr
# total_bill vs bold totalbill correlations is 1 becuz they are same variable
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_corr, annot = True)
# we check if two variables are highly correlated then we can remove one 
# of the data

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flight_pivot = flights.pivot_table(index ='month' , columns ='year' , values = 'passengers')
flight_pivot
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flight_pivot)

# %%
sns.heatmap(flight_pivot,cmap = 'coolwarm')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
survived = titanic['survived']
age = titanic['age']

# %%
age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
sns.jointplot(x ='survived' , y = 'age' , data = titanic, color ='r', kind = 'kde')
